# %% [markdown]
# # Fitting ALPS through GCV

# %% [markdown]
# Interpolates data to daily values. Adapted from source below. Needs the accompanying Functions.py file to run. The code, as written, expects the input data as .csv files beginning with a 3-digit Glacier Identification code (GID or glacierid). Default code assumes the data is saved with a column 'Date' in datetime format and a 'Mean Variable' column with the data you wish to interpolate.
#
# Interpolated data is saved as a .csv file without headers with three columns of data: decimal year, interpolated data, and the date in YYYYMMDD format.
#
# Source: Shekhar, P., Csatho, B., Schenk, T., Roberts, C., and Patra, A. K.: Alps: a unified framework for modeling time series of land ice changes, IEEE Transactions on Geoscience and Remote Sensing, 59, 6466–6481, 2020.
#
# Access: https://github.com/pshekhar-tufts/ALPS

# %% [markdown]
# ### Import dependencies, helper functions

# %%
import os
import pickle
from Functions import *
from matplotlib.pyplot import *
import numpy as np
import pandas as pd
from datetime import datetime as dt
from datetime import datetime, timedelta
import time
from datetime import date

import warnings
warnings.filterwarnings('ignore')

# %%
def toYearFraction(date):
    def sinceEpoch(date): # returns seconds since epoch
        return time.mktime(date.timetuple())
    s = sinceEpoch

    year = date.year
    startOfThisYear = dt(year=year, month=1, day=1)
    startOfNextYear = dt(year=year+1, month=1, day=1)

    yearElapsed = s(date) - s(startOfThisYear)
    yearDuration = s(startOfNextYear) - s(startOfThisYear)
    fraction = yearElapsed/yearDuration

    return date.year + fraction

# %% [markdown]
# ## Main function

# %%
# set a threshold. this should be 000 unless you need to rerun the code starting after a certain number
threshold = 0

# %%
# Define the directory path
in_dir  = '/Users/.../original/'
out_dir = '/.../interpolated/'

# Get all filenames in the directory and sort them by the first three digits (GID)
csv_files = [filename for filename in os.listdir(in_dir) if filename.endswith('.csv')] 
csv_files.sort(key=lambda x: int(x[:3]))
filtered_files = [filename for filename in csv_files if int(filename[:3]) > threshold]

# Loop through the sorted list of files
for filename in filtered_files:
    if filename.endswith('.csv'):
        glacierid = filename[:3]
        print(f"Processing glacier {glacierid}...")

        # Load the data for the current glacier
        data = pd.read_csv(os.path.join(in_dir, filename))
        data['time'] = pd.to_datetime(data['time'])  
        data = data.dropna(subset=['Mean Variable']).reset_index(drop=True) 
        data = data.groupby(pd.PeriodIndex(data['time'], freq="M"))['Mean Variable'].mean().reset_index()
        data['time'] = data['time'].astype(str)
        data['time'] = pd.to_datetime(data['time'])
        data_arrays = data[['time', 'Mean Variable']].to_numpy()

        decdate = [] 
        for i in range(len(data_arrays)):
            new = data_arrays[i, 0]
            new = toYearFraction(new)
            decdate.append(new)

        data['Dec_Date'] = decdate

        # Update data_arrays with the decimal date and 'Terminus Position'
        data_arrays = data[['Dec_Date', 'Mean Variable']].to_numpy()

        # Calculate the number of days between first and last dates
        d0 = data['time'].iloc[0]
        d1 = data['time'].iloc[-1]
        delta = d1 - d0
        num = delta.days + 1

        # setup interpolation. See source paper for discussion on changing values of p and q
        p = 4
        q = 1
        [n, lamb, sigmasq] = full_search_nk(data_arrays, p, q)
        c = n + p
        U = Kno_pspline_opt(data_arrays, p, n)
        B = Basis_Pspline(n, p, U, data_arrays[:, 0])
        P = Penalty_p(q, c)
        theta = np.linalg.solve(B.T.dot(B) + lamb * P, B.T.dot(data_arrays[:, 1].reshape(-1, 1)))

        # Getting the mean of the prediction
        xpred = np.linspace(data_arrays[0, 0], data_arrays[-1, 0], num)
        Bpred = Basis_Pspline(n, p, U, xpred)
        ypred1 = Bpred.dot(theta)
        std_t1, std_n1 = Var_bounds(data_arrays, Bpred, B, theta, P, lamb)

        # Save the interpolated data as an array, adding an integer date column
        ypred1 = np.squeeze(ypred1)  # Make sure the y-value array is 1D
        sdate = data['time'].iloc[0]
        last = data['time'].iloc[-1]
        edate = last + timedelta(days=1)
        dates = pd.date_range(sdate, edate - timedelta(days=1), freq='d')
        datesint = [0] * len(dates)
        for i in range(len(dates)):
            datesint[i] = int(dates[i].strftime('%Y%m%d'))
        ALPS_array = np.array((xpred, ypred1, datesint)).T  # Transpose

        # Save the results with the glacierid in the filename
        output_filename = os.path.join(out_dir, f"{glacierid}_variable.csv")
        np.savetxt(output_filename, ALPS_array, delimiter=",")  # Save as a .csv
        print(f"Saved interpolated data for glacier {glacierid} to {output_filename}")
# Out:
# Saved interpolated data for glacier 077 to /Users/kevin/Documents/ML_longterm/variables_data/discharge/time_series/interpolated/077_discharge_MAR_interpolated.csv
# Processing glacier 078...
# Saved interpolated data for glacier 078 to /Users/kevin/Documents/ML_longterm/variables_data/discharge/time_series/interpolated/078_discharge_MAR_interpolated.csv
# Processing glacier 080...
# Saved interpolated data for glacier 080 to /Users/kevin/Documents/ML_longterm/variables_data/discharge/time_series/interpolated/080_discharge_MAR_interpolated.csv
# Processing glacier 085...
# Saved interpolated data for glacier 085 to /Users/kevin/Documents/ML_longterm/variables_data/discharge/time_series/interpolated/085_discharge_MAR_interpolated.csv
# Processing glacier 088...
# Saved interpolated data for glacier 088 to /Users/kevin/Documents/ML_longterm/variables_data/discharge/time_series/interpolated/088_discharge_MAR_interpolated.csv
# Processing glacier 090...
# Saved interpolated data for glacier 090 to /Users/kevin/Documents/ML_longterm/variables_data/discharge/time_series/interpolated/090_discharge_MAR_interpolated.csv
# Processing glacier 091...
# Saved interpolated data for glacier 091 to /Users/kevin/Documents/ML_longterm/variables_data/discharge/time_series/interpolated/091_discharge_MAR_interpolated.csv
# Processing glacier 097...
# Saved interpolated data for glacier 097 to /Users/kevin/Documents/ML_longterm/variables_data/discharge/time_series/interpolated/097_discharge_MAR_interpolated.csv
# Processing glacier 098...
# Saved interpolated data for glacier 098 to /Users/kevin/Documents/ML_longterm/variables_data/discharge/time_series/interpolated/098_discharge_MAR_interpolated.csv
# Processing glacier 099...
# Saved interpolated data for glacier 099 to /Users/kevin/Documents/ML_longterm/variables_data/discharge/time_series/interpolated/099_discharge_MAR_interpolated.csv
# Processing glacier 101...
# Saved interpolated data for glacier 101 to /Users/kevin/Documents/ML_longterm/variables_data/discharge/time_series/interpolated/101_discharge_MAR_interpolated.csv
# Processing glacier 102...
# Saved interpolated data for glacier 102 to /Users/kevin/Documents/ML_longterm/variables_data/discharge/time_series/interpolated/102_discharge_MAR_interpolated.csv
# Processing glacier 110...
# Saved interpolated data for glacier 110 to /Users/kevin/Documents/ML_longterm/variables_data/discharge/time_series/interpolated/110_discharge_MAR_interpolated.csv
# Processing glacier 113...
# Saved interpolated data for glacier 113 to /Users/kevin/Documents/ML_longterm/variables_data/discharge/time_series/interpolated/113_discharge_MAR_interpolated.csv
# Processing glacier 114...
# Saved interpolated data for glacier 114 to /Users/kevin/Documents/ML_longterm/variables_data/discharge/time_series/interpolated/114_discharge_MAR_interpolated.csv
# Processing glacier 116...
# Saved interpolated data for glacier 116 to /Users/kevin/Documents/ML_longterm/variables_data/discharge/time_series/interpolated/116_discharge_MAR_interpolated.csv
# Processing glacier 118...
# Saved interpolated data for glacier 118 to /Users/kevin/Documents/ML_longterm/variables_data/discharge/time_series/interpolated/118_discharge_MAR_interpolated.csv
# Processing glacier 121...
# Saved interpolated data for glacier 121 to /Users/kevin/Documents/ML_longterm/variables_data/discharge/time_series/interpolated/121_discharge_MAR_interpolated.csv
# Processing glacier 125...
# Saved interpolated data for glacier 125 to /Users/kevin/Documents/ML_longterm/variables_data/discharge/time_series/interpolated/125_discharge_MAR_interpolated.csv
# Processing glacier 132...
# Saved interpolated data for glacier 132 to /Users/kevin/Documents/ML_longterm/variables_data/discharge/time_series/interpolated/132_discharge_MAR_interpolated.csv
# Processing glacier 145...
# Saved interpolated data for glacier 145 to /Users/kevin/Documents/ML_longterm/variables_data/discharge/time_series/interpolated/145_discharge_MAR_interpolated.csv
# Processing glacier 152...
# Saved interpolated data for glacier 152 to /Users/kevin/Documents/ML_longterm/variables_data/discharge/time_series/interpolated/152_discharge_MAR_interpolated.csv
# Processing glacier 157...
# Saved interpolated data for glacier 157 to /Users/kevin/Documents/ML_longterm/variables_data/discharge/time_series/interpolated/157_discharge_MAR_interpolated.csv
# Processing glacier 163...
# Saved interpolated data for glacier 163 to /Users/kevin/Documents/ML_longterm/variables_data/discharge/time_series/interpolated/163_discharge_MAR_interpolated.csv
# Processing glacier 167...
# Saved interpolated data for glacier 167 to /Users/kevin/Documents/ML_longterm/variables_data/discharge/time_series/interpolated/167_discharge_MAR_interpolated.csv
# Processing glacier 171...
# Saved interpolated data for glacier 171 to /Users/kevin/Documents/ML_longterm/variables_data/discharge/time_series/interpolated/171_discharge_MAR_interpolated.csv
# Processing glacier 172...
# Saved interpolated data for glacier 172 to /Users/kevin/Documents/ML_longterm/variables_data/discharge/time_series/interpolated/172_discharge_MAR_interpolated.csv
# Processing glacier 180...
# Saved interpolated data for glacier 180 to /Users/kevin/Documents/ML_longterm/variables_data/discharge/time_series/interpolated/180_discharge_MAR_interpolated.csv
# Processing glacier 181...
# Saved interpolated data for glacier 181 to /Users/kevin/Documents/ML_longterm/variables_data/discharge/time_series/interpolated/181_discharge_MAR_interpolated.csv
# Processing glacier 185...
# Saved interpolated data for glacier 185 to /Users/kevin/Documents/ML_longterm/variables_data/discharge/time_series/interpolated/185_discharge_MAR_interpolated.csv
# Processing glacier 186...
# Saved interpolated data for glacier 186 to /Users/kevin/Documents/ML_longterm/variables_data/discharge/time_series/interpolated/186_discharge_MAR_interpolated.csv
# Processing glacier 187...
# Saved interpolated data for glacier 187 to /Users/kevin/Documents/ML_longterm/variables_data/discharge/time_series/interpolated/187_discharge_MAR_interpolated.csv
# Processing glacier 189...
# Saved interpolated data for glacier 189 to /Users/kevin/Documents/ML_longterm/variables_data/discharge/time_series/interpolated/189_discharge_MAR_interpolated.csv
# Processing glacier 195...
# Saved interpolated data for glacier 195 to /Users/kevin/Documents/ML_longterm/variables_data/discharge/time_series/interpolated/195_discharge_MAR_interpolated.csv
# Processing glacier 196...
# Saved interpolated data for glacier 196 to /Users/kevin/Documents/ML_longterm/variables_data/discharge/time_series/interpolated/196_discharge_MAR_interpolated.csv
# Processing glacier 197...
# Saved interpolated data for glacier 197 to /Users/kevin/Documents/ML_longterm/variables_data/discharge/time_series/interpolated/197_discharge_MAR_interpolated.csv
# Processing glacier 210...
# Saved interpolated data for glacier 210 to /Users/kevin/Documents/ML_longterm/variables_data/discharge/time_series/interpolated/210_discharge_MAR_interpolated.csv
# Processing glacier 212...
# Saved interpolated data for glacier 212 to /Users/kevin/Documents/ML_longterm/variables_data/discharge/time_series/interpolated/212_discharge_MAR_interpolated.csv
# Processing glacier 223...
# Saved interpolated data for glacier 223 to /Users/kevin/Documents/ML_longterm/variables_data/discharge/time_series/interpolated/223_discharge_MAR_interpolated.csv
# Processing glacier 227...
# Saved interpolated data for glacier 227 to /Users/kevin/Documents/ML_longterm/variables_data/discharge/time_series/interpolated/227_discharge_MAR_interpolated.csv
# Processing glacier 228...
# Saved interpolated data for glacier 228 to /Users/kevin/Documents/ML_longterm/variables_data/discharge/time_series/interpolated/228_discharge_MAR_interpolated.csv
# Processing glacier 229...
# Saved interpolated data for glacier 229 to /Users/kevin/Documents/ML_longterm/variables_data/discharge/time_series/interpolated/229_discharge_MAR_interpolated.csv
# Processing glacier 231...
# Saved interpolated data for glacier 231 to /Users/kevin/Documents/ML_longterm/variables_data/discharge/time_series/interpolated/231_discharge_MAR_interpolated.csv
# Processing glacier 233...
# Saved interpolated data for glacier 233 to /Users/kevin/Documents/ML_longterm/variables_data/discharge/time_series/interpolated/233_discharge_MAR_interpolated.csv
# Processing glacier 234...
# Saved interpolated data for glacier 234 to /Users/kevin/Documents/ML_longterm/variables_data/discharge/time_series/interpolated/234_discharge_MAR_interpolated.csv
# Processing glacier 235...
# Saved interpolated data for glacier 235 to /Users/kevin/Documents/ML_longterm/variables_data/discharge/time_series/interpolated/235_discharge_MAR_interpolated.csv
# Processing glacier 240...
# Saved interpolated data for glacier 240 to /Users/kevin/Documents/ML_longterm/variables_data/discharge/time_series/interpolated/240_discharge_MAR_interpolated.csv
# Processing glacier 242...
# Saved interpolated data for glacier 242 to /Users/kevin/Documents/ML_longterm/variables_data/discharge/time_series/interpolated/242_discharge_MAR_interpolated.csv
# Processing glacier 243...
# Saved interpolated data for glacier 243 to /Users/kevin/Documents/ML_longterm/variables_data/discharge/time_series/interpolated/243_discharge_MAR_interpolated.csv
# Processing glacier 246...
# Saved interpolated data for glacier 246 to /Users/kevin/Documents/ML_longterm/variables_data/discharge/time_series/interpolated/246_discharge_MAR_interpolated.csv
# Processing glacier 247...
# Saved interpolated data for glacier 247 to /Users/kevin/Documents/ML_longterm/variables_data/discharge/time_series/interpolated/247_discharge_MAR_interpolated.csv
# Processing glacier 248...
# Saved interpolated data for glacier 248 to /Users/kevin/Documents/ML_longterm/variables_data/discharge/time_series/interpolated/248_discharge_MAR_interpolated.csv
# Processing glacier 251...
# Saved interpolated data for glacier 251 to /Users/kevin/Documents/ML_longterm/variables_data/discharge/time_series/interpolated/251_discharge_MAR_interpolated.csv
# Processing glacier 252...
# Saved interpolated data for glacier 252 to /Users/kevin/Documents/ML_longterm/variables_data/discharge/time_series/interpolated/252_discharge_MAR_interpolated.csv
# Processing glacier 253...
# Saved interpolated data for glacier 253 to /Users/kevin/Documents/ML_longterm/variables_data/discharge/time_series/interpolated/253_discharge_MAR_interpolated.csv
# Processing glacier 255...
# Saved interpolated data for glacier 255 to /Users/kevin/Documents/ML_longterm/variables_data/discharge/time_series/interpolated/255_discharge_MAR_interpolated.csv
# Processing glacier 256...
# Saved interpolated data for glacier 256 to /Users/kevin/Documents/ML_longterm/variables_data/discharge/time_series/interpolated/256_discharge_MAR_interpolated.csv
# Processing glacier 273...
# Saved interpolated data for glacier 273 to /Users/kevin/Documents/ML_longterm/variables_data/discharge/time_series/interpolated/273_discharge_MAR_interpolated.csv
# Processing glacier 275...
# Saved interpolated data for glacier 275 to /Users/kevin/Documents/ML_longterm/variables_data/discharge/time_series/interpolated/275_discharge_MAR_interpolated.csv
# Processing glacier 278...
# Saved interpolated data for glacier 278 to /Users/kevin/Documents/ML_longterm/variables_data/discharge/time_series/interpolated/278_discharge_MAR_interpolated.csv
# Processing glacier 279...
# Saved interpolated data for glacier 279 to /Users/kevin/Documents/ML_longterm/variables_data/discharge/time_series/interpolated/279_discharge_MAR_interpolated.csv
# Processing glacier 280...
# Saved interpolated data for glacier 280 to /Users/kevin/Documents/ML_longterm/variables_data/discharge/time_series/interpolated/280_discharge_MAR_interpolated.csv
# Processing glacier 281...
# Saved interpolated data for glacier 281 to /Users/kevin/Documents/ML_longterm/variables_data/discharge/time_series/interpolated/281_discharge_MAR_interpolated.csv
# Processing glacier 282...
# Saved interpolated data for glacier 282 to /Users/kevin/Documents/ML_longterm/variables_data/discharge/time_series/interpolated/282_discharge_MAR_interpolated.csv
# Processing glacier 283...
# Saved interpolated data for glacier 283 to /Users/kevin/Documents/ML_longterm/variables_data/discharge/time_series/interpolated/283_discharge_MAR_interpolated.csv
# Processing glacier 284...
# Saved interpolated data for glacier 284 to /Users/kevin/Documents/ML_longterm/variables_data/discharge/time_series/interpolated/284_discharge_MAR_interpolated.csv
# Processing glacier 285...
# Saved interpolated data for glacier 285 to /Users/kevin/Documents/ML_longterm/variables_data/discharge/time_series/interpolated/285_discharge_MAR_interpolated.csv
# Processing glacier 286...
# Saved interpolated data for glacier 286 to /Users/kevin/Documents/ML_longterm/variables_data/discharge/time_series/interpolated/286_discharge_MAR_interpolated.csv
# Processing glacier 288...
# Saved interpolated data for glacier 288 to /Users/kevin/Documents/ML_longterm/variables_data/discharge/time_series/interpolated/288_discharge_MAR_interpolated.csv
# Processing glacier 290...
# Saved interpolated data for glacier 290 to /Users/kevin/Documents/ML_longterm/variables_data/discharge/time_series/interpolated/290_discharge_MAR_interpolated.csv
# Processing glacier 291...
# Saved interpolated data for glacier 291 to /Users/kevin/Documents/ML_longterm/variables_data/discharge/time_series/interpolated/291_discharge_MAR_interpolated.csv
